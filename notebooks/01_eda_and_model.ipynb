# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
import os
# Out:
# CWD ajustado: C:\Users\Italo\Documents\projetos git\Customer Churn Prediction – Predicting Customer Loss Using Machine Learning

# %%
df = pd.read_csv("data/raw/Telco-Customer-Churn.csv")
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure InternetService  \
# 0    Male              0     Yes         No      18     Fiber optic
# 1  Female              0      No        Yes       7             DSL
# 2    Male              0     Yes        Yes      62             DSL
# 3    Male              1     Yes         No      45     Fiber optic
# 4    Male              0      No         No      16              No
#
#          Contract  MonthlyCharges  TotalCharges Churn
# 0  Month-to-month       85.961453   1546.642467   Yes
# 1        One year       52.608841    390.301146   Yes
# 2        Two year       44.366670   2754.972204    No
# 3        Two year      106.478963   4799.155683    No
# 4  Month-to-month       18.404272    331.479981    No

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   gender           5000 non-null   object
#  1   SeniorCitizen    5000 non-null   int64
#  2   Partner          4900 non-null   object
#  3   Dependents       5000 non-null   object
#  4   tenure           5000 non-null   int64
#  5   InternetService  4900 non-null   object
#  6   Contract         5000 non-null   object
#  7   MonthlyCharges   4900 non-null   float64
#  8   TotalCharges     4900 non-null   float64
#  9   Churn            5000 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 390.8+ KB
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    5000.000000  5000.000000     4900.000000   4900.000000
# mean        0.145000    36.473000       70.990356   2588.712122
# std         0.352136    20.635844       26.800966   1847.484896
# min         0.000000     1.000000       15.039771      0.000000
# 25%         0.000000    19.000000       50.560413   1056.856418
# 50%         0.000000    37.000000       72.535001   2239.024662
# 75%         0.000000    54.000000       91.557919   3839.487687
# max         1.000000    72.000000      119.994528   8524.715045

# %%
sns.countplot(data=df, x="Churn")
plt.title("Distribuição de Churn")
plt.show()

# %%
plt.figure(figsize=(14,8))
sns.heatmap(df.corr(numeric_only=True), cmap="viridis")
plt.title("Correlation Matrix")
plt.show()
